# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
import tensorflow as tf
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle
from PIL import Image
from six.moves import range

# %%
pickle_file= 'banglaIsolated_clean.pickle'

with open(pickle_file, 'rb') as f:
    save=pickle.load(f)
    train_dataset=save['train_dataset']
    train_labels=save['train_labels']
    valid_dataset=save['valid_dataset_clean']
    valid_labels=save['valid_labels']
    test_dataset=save['test_dataset_clean']
    test_labels=save['test_labels']
    del save #hint to help gc to free up memory 
    print('training set', train_dataset.shape,train_labels.shape)
    print('validation set', valid_dataset.shape, valid_labels.shape)
    print('test set', test_dataset.shape,test_labels.shape)
# Out:
# training set (139000, 28, 28) (139000,)
# validation set (10000, 28, 28) (10000,)
# test set (10000, 28, 28) (10000,)

# %%
image_size=28
num_labels=84
num_channels=1 

def reformat(dataset, labels):
    dataset=dataset.reshape((-1,image_size,image_size,num_channels)).astype(np.float32)
    # Map 1 to [0.0,1.0,0.0....], 2 to [0.0,0.0,1.0.....]
    labels=(np.arange(num_labels) ==labels[:,None]).astype(np.float32)
    return dataset,labels
train_dataset, train_labels= reformat(train_dataset, train_labels)
valid_dataset, valid_labels=reformat(valid_dataset, valid_labels)
test_dataset, test_labels =reformat(test_dataset, test_labels)
print( 'training set', train_dataset.shape,train_labels.shape)
print('validation set', valid_dataset.shape,valid_labels.shape)
print('test set', test_dataset.shape,test_labels.shape)
# Out:
# training set (139000, 28, 28, 1) (139000, 84)
# validation set (10000, 28, 28, 1) (10000, 84)
# test set (10000, 28, 28, 1) (10000, 84)

# %%
def accuracy(predictions, labels):
    return(100.0*np.sum(np.argmax(predictions, 1)==np.argmax(labels,1))/ predictions.shape[0])

# %%
def deeper_inception_conv_net():
    
    batch_size = 50
    patch_size1 = 3
    patch_size2 = 5
    depth = 16
    depth1 = 32
    depth2 = 16
    depth3 = 8
    concat_depth = 48
    num_hidden = 800
    num_hidden2 = 400
    keep_prob = 0.5
    decay_step = 2000
    base = 0.9

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, num_channels, depth], stddev=0.3))
      layer1_biases = tf.Variable(tf.zeros([depth]))
      layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size2, patch_size2, depth, depth1], stddev=0.05))
      layer2_biases = tf.Variable(tf.constant(0.0, shape=[depth1]))
      layer3_weights = tf.Variable(tf.truncated_normal(
          [((image_size + 3) // 4) * ((image_size + 3) // 4) * concat_depth, num_hidden], stddev=0.05))
      layer3_biases = tf.Variable(tf.constant(0.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_hidden2], stddev=0.01))
      layer4_biases = tf.Variable(tf.constant(0.0, shape=[num_hidden2]))
      layer5_weights = tf.Variable(tf.truncated_normal(
          [num_hidden2, num_labels], stddev=0.01))
      layer5_biases = tf.Variable(tf.constant(0.0, shape=[num_labels]))
        
      inception1x1_weights = tf.Variable(tf.truncated_normal(
          [1, 1, depth1, depth2], stddev=0.25))
      inception1x1_biases = tf.Variable(tf.constant(0.0, shape=[depth2]))
      inception3x3_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, depth2, depth3], stddev=0.05))
      inception3x3_biases = tf.Variable(tf.constant(0.0, shape=[depth3]))
      inception5x5_weights = tf.Variable(tf.truncated_normal(
          [patch_size2, patch_size2, depth2, depth3], stddev=0.08))
      inception5x5_biases = tf.Variable(tf.constant(0.0, shape=[depth3]))
    
      inception1x1_post_mxpool_wts = tf.Variable(tf.truncated_normal(
          [1, 1, depth1, depth2], stddev=0.04))
      post_maxpool_biases = tf.Variable(tf.constant(0.0, shape=[depth2]))
        
      global_step = tf.Variable(0, trainable = False)  # count the number of steps taken.
      learning_rate = tf.train.exponential_decay(0.005, global_step, decay_step, base)

        
      # Model.
      def model(data, useDropout):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer2_biases)
        
        inception1x1_conv = tf.nn.conv2d(hidden, inception1x1_weights, [1, 1, 1, 1], padding='SAME')
        inception1x1_relu = tf.nn.relu(inception1x1_conv + inception1x1_biases)
        
        inception3x3_conv = tf.nn.conv2d(inception1x1_relu, inception3x3_weights, [1, 1, 1, 1], padding='SAME')
        inception3x3_relu = tf.nn.relu(inception3x3_conv + inception3x3_biases)
        
        inception5x5_conv = tf.nn.conv2d(inception1x1_relu, inception5x5_weights, [1, 1, 1, 1], padding='SAME')
        inception5x5_relu = tf.nn.relu(inception5x5_conv + inception5x5_biases)
        
        inception3x3_maxpool = tf.nn.max_pool(hidden, [1, 3, 3, 1], [1, 1, 1, 1], padding='SAME')
        inception1x1_post_maxpool = tf.nn.conv2d(inception3x3_maxpool, inception1x1_post_mxpool_wts, [1, 1, 1, 1], padding='SAME')
        inception1x1_post_maxpool = tf.nn.relu(inception1x1_post_maxpool + post_maxpool_biases)
        
        concat_filter = tf.concat([inception1x1_relu, inception3x3_relu, inception5x5_relu, inception1x1_post_maxpool],3)
        concat_maxpooled = tf.nn.max_pool(concat_filter, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = concat_maxpooled.get_shape().as_list()
        
        reshape = tf.reshape(concat_maxpooled, [shape[0], shape[1] * shape[2] * shape[3]])
    
        if useDropout == 1:
            dropout_layer2 = tf.nn.dropout(tf.nn.relu(reshape), keep_prob)
        else:
            dropout_layer2 = tf.nn.relu(reshape)
        hidden = tf.nn.relu(tf.matmul(dropout_layer2, layer3_weights) + layer3_biases)
        
        hidden = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
        return tf.matmul(hidden, layer5_weights) + layer5_biases

      # Training computation.
      logits = model(tf_train_dataset, 1)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))

      # Optimizer.
      optimizer = tf.train.AdamOptimizer(0.001).minimize(loss, global_step=global_step)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(model(tf_train_dataset, 0))
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 0))
      test_prediction = tf.nn.softmax(model(tf_test_dataset, 0))
        
        
        
    num_steps = 30001

    with tf.Session(graph=graph) as session:
      tf.initialize_all_variables().run()
      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          #print(tf.Print(layer1_weights, [layer1_weights]).eval())
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels)) 
    
deeper_inception_conv_net()
# Out:
# WARNING:tensorflow:From <ipython-input-7-1c6d846308d5>:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 4.429036
# Minibatch accuracy: 2.0%
# Validation accuracy: 1.2%
# Minibatch loss at step 50: 4.372962
# Minibatch accuracy: 0.0%
# Validation accuracy: 1.4%
# Minibatch loss at step 100: 3.578324
# Minibatch accuracy: 6.0%
# Validation accuracy: 10.3%
# Minibatch loss at step 150: 2.978653
# Minibatch accuracy: 22.0%
# Validation accuracy: 18.7%
# Minibatch loss at step 200: 2.944012
# Minibatch accuracy: 22.0%
# Validation accuracy: 23.2%
# Minibatch loss at step 250: 2.175531
# Minibatch accuracy: 42.0%
# Validation accuracy: 32.2%
# Minibatch loss at step 300: 2.185088
# Minibatch accuracy: 34.0%
# Validation accuracy: 37.3%
# Minibatch loss at step 350: 2.214743
# Minibatch accuracy: 42.0%
# Validation accuracy: 42.8%
# Minibatch loss at step 400: 2.197753
# Minibatch accuracy: 36.0%
# Validation accuracy: 46.1%
# Minibatch loss at step 450: 2.026418
# Minibatch accuracy: 40.0%
# Validation accuracy: 48.4%
# Minibatch loss at step 500: 1.787586
# Minibatch accuracy: 92.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 5000: 0.470971
# Minibatch accuracy: 88.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 5050: 0.461702
# Minibatch accuracy: 86.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 5100: 0.668018
# Minibatch accuracy: 86.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 5150: 0.501962
# Minibatch accuracy: 90.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 5200: 0.724748
# Minibatch accuracy: 80.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 5250: 0.372326
# Minibatch accuracy: 84.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 5300: 0.736135
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 5350: 0.375379
# Minibatch accuracy: 88.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 5400: 0.737397
# Minibatch accuracy: 78.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 5450: 0.590296
# Minibatch accuracy: 90.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 5500: 0.560751
# Minibatch accuracy: 86.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 5550: 0.506037
# Minibatch accuracy: 90.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 5600: 0.424612
# Minibatch accuracy: 88.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 5650: 0.958183
# Minibatch accuracy: 78.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 5700: 0.595301
# Minibatch accuracy: 90.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 5750: 0.981579
# Minibatch accuracy: 84.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 5800: 0.778757
# Minibatch accuracy: 84.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 5850: 0.670129
# Minibatch accuracy: 78.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 5900: 0.429570
# Minibatch accuracy: 88.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 5950: 0.497044
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 6000: 0.548105
# Minibatch accuracy: 86.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 6050: 0.435736
# Minibatch accuracy: 88.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 6100: 0.363415
# Minibatch accuracy: 92.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 6150: 0.474968
# Minibatch accuracy: 88.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 6200: 0.501831
# Minibatch accuracy: 84.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 6250: 0.546523
# Minibatch accuracy: 92.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 6300: 0.562922
# Minibatch accuracy: 90.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 6350: 0.406826
# Minibatch accuracy: 92.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 6400: 0.736900
# Minibatch accuracy: 78.0%
# Minibatch accuracy: 86.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 12400: 0.478575
# Minibatch accuracy: 94.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 12450: 0.885853
# Minibatch accuracy: 80.0%
# Validation accuracy: 90.1%
# Minibatch loss at step 12500: 0.485628
# Minibatch accuracy: 88.0%
# Validation accuracy: 91.1%
# Minibatch loss at step 12550: 0.403843
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 12600: 0.261867
# Minibatch accuracy: 96.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 12650: 0.545941
# Minibatch accuracy: 88.0%
# Validation accuracy: 91.0%
# Minibatch loss at step 12700: 0.664090
# Minibatch accuracy: 84.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 12750: 0.470219
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 12800: 0.568156
# Minibatch accuracy: 86.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 12850: 0.477035
# Minibatch accuracy: 92.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 12900: 0.394107
# Minibatch accuracy: 96.0%
# Validation accuracy: 91.0%
# Minibatch loss at step 12950: 0.325140
# Minibatch accuracy: 92.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 13000: 0.310299
# Minibatch accuracy: 96.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 13050: 0.329597
# Minibatch accuracy: 94.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 13100: 0.417758
# Minibatch accuracy: 92.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 13150: 0.314905
# Minibatch accuracy: 92.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 13200: 0.509128
# Minibatch accuracy: 92.0%
# Validation accuracy: 91.2%
# Minibatch loss at step 13250: 0.217637
# Minibatch accuracy: 96.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 13300: 0.439595
# Minibatch accuracy: 90.0%
# Validation accuracy: 91.0%
# Minibatch loss at step 13350: 0.307561
# Minibatch accuracy: 96.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 13400: 0.338842
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 13450: 0.196774
# Minibatch accuracy: 94.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 13500: 0.431571
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 13550: 0.315610
# Minibatch accuracy: 94.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 13600: 0.622203
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 13650: 0.246854
# Minibatch accuracy: 92.0%
# Validation accuracy: 91.3%
# Minibatch loss at step 13700: 0.607115
# Minibatch accuracy: 88.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 13750: 0.295546
# Minibatch accuracy: 94.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 13800: 0.274987
# Minibatch accuracy: 94.0%
# Validation accuracy: 90.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 18300: 0.255433
# Minibatch accuracy: 96.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 18350: 0.397010
# Minibatch accuracy: 90.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 18400: 0.259273
# Minibatch accuracy: 96.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 18450: 0.522072
# Minibatch accuracy: 94.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 18500: 0.443390
# Minibatch accuracy: 92.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 18550: 0.580324
# Minibatch accuracy: 80.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 18600: 0.352100
# Minibatch accuracy: 92.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 18650: 0.453977
# Minibatch accuracy: 88.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 18700: 0.581668
# Minibatch accuracy: 92.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 18750: 0.401111
# Minibatch accuracy: 96.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 18800: 0.354736
# Minibatch accuracy: 86.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 18850: 0.168385
# Minibatch accuracy: 96.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 18900: 0.320172
# Minibatch accuracy: 90.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 18950: 0.422356
# Minibatch accuracy: 94.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 19000: 0.419011
# Minibatch accuracy: 90.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 19050: 0.195751
# Minibatch accuracy: 98.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 19100: 0.271845
# Minibatch accuracy: 92.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 19150: 0.301161
# Minibatch accuracy: 92.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 19200: 0.274472
# Minibatch accuracy: 96.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 19250: 0.307018
# Minibatch accuracy: 94.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 19300: 0.381185
# Minibatch accuracy: 90.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 19350: 0.186109
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 19400: 0.403675
# Minibatch accuracy: 88.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 19450: 0.250933
# Minibatch accuracy: 92.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 19500: 0.218868
# Minibatch accuracy: 92.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 19550: 0.509342
# Minibatch accuracy: 86.0%
# Validation accuracy: 92.8%
# Minibatch loss at step 19600: 0.494018
# Minibatch accuracy: 92.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 19650: 0.529044
# Minibatch accuracy: 90.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 19700: 0.322848
# Minibatch accuracy: 94.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 19750: 0.486664
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 24250: 0.241635
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 24300: 0.286192
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 24350: 0.270161
# Minibatch accuracy: 94.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 24400: 0.335308
# Minibatch accuracy: 92.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 24450: 0.270230
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.4%
# Minibatch loss at step 24500: 0.416326
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.6%
# Minibatch loss at step 24550: 0.212829
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.4%
# Minibatch loss at step 24600: 0.310456
# Minibatch accuracy: 98.0%
# Validation accuracy: 93.2%
# Minibatch loss at step 24650: 0.251916
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 24700: 0.548149
# Minibatch accuracy: 96.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 24750: 0.111792
# Minibatch accuracy: 98.0%
# Validation accuracy: 93.4%
# Minibatch loss at step 24800: 0.449530
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.6%
# Minibatch loss at step 24850: 0.383477
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 24900: 0.491916
# Minibatch accuracy: 92.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 24950: 0.383024
# Minibatch accuracy: 92.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 25000: 0.206345
# Minibatch accuracy: 96.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 25050: 0.379000
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 25100: 0.485380
# Minibatch accuracy: 88.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 25150: 0.253798
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 25200: 0.398896
# Minibatch accuracy: 86.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 25250: 0.354056
# Minibatch accuracy: 94.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 25300: 0.248392
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 25350: 0.149498
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.2%
# Minibatch loss at step 25400: 0.202675
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 25450: 0.254130
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 25500: 0.203308
# Minibatch accuracy: 96.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 25550: 0.172587
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.2%
# Minibatch loss at step 25600: 0.170432
# Minibatch accuracy: 96.0%
# Validation accuracy: 92.8%
# Minibatch loss at step 25650: 0.171574
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.2%
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.4%
# Minibatch loss at step 27200: 0.259427
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.7%
# Minibatch loss at step 27250: 0.446731
# Minibatch accuracy: 88.0%
# Validation accuracy: 93.7%
# Minibatch loss at step 27300: 0.557256
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.2%
# Minibatch loss at step 27350: 0.283170
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.6%
# Minibatch loss at step 27400: 0.540414
# Minibatch accuracy: 86.0%
# Validation accuracy: 93.5%
# Minibatch loss at step 27450: 0.301150
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.4%
# Minibatch loss at step 27500: 0.211087
# Minibatch accuracy: 98.0%
# Validation accuracy: 93.5%
# Minibatch loss at step 27550: 0.315808
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 27600: 0.177068
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 27650: 0.386044
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.5%
# Minibatch loss at step 27700: 0.337705
# Minibatch accuracy: 92.0%
# Validation accuracy: 93.8%
# Minibatch loss at step 27750: 0.322042
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.8%
# Minibatch loss at step 27800: 0.361080
# Minibatch accuracy: 92.0%
# Validation accuracy: 94.0%
# Minibatch loss at step 27850: 0.160194
# Minibatch accuracy: 98.0%
# Validation accuracy: 93.9%
# Minibatch loss at step 27900: 0.312498
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 27950: 0.087444
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.6%
# Minibatch loss at step 28000: 0.342272
# Minibatch accuracy: 90.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 28050: 0.156308
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.2%
# Minibatch loss at step 28100: 0.313942
# Minibatch accuracy: 98.0%
# Validation accuracy: 93.5%
# Minibatch loss at step 28150: 0.160464
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.5%
# Minibatch loss at step 28200: 0.287043
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.7%
# Minibatch loss at step 28250: 0.446678
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.2%
# Minibatch loss at step 28300: 0.411174
# Minibatch accuracy: 92.0%
# Validation accuracy: 93.2%
# Minibatch loss at step 28350: 0.376496
# Minibatch accuracy: 92.0%
# Validation accuracy: 93.6%
# Minibatch loss at step 28400: 0.228469
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.7%
# Minibatch loss at step 28450: 0.145116
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.8%
# Minibatch loss at step 28500: 0.164296
# Minibatch accuracy: 96.0%
# Validation accuracy: 94.1%
# Minibatch loss at step 28550: 0.081479
# Minibatch accuracy: 98.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 28600: 0.162350
# Minibatch accuracy: 98.0%
# Validation accuracy: 93.9%

# %%
quries
